# %% [markdown]
# <a href="https://colab.research.google.com/github/aashutoshraj521/Python/blob/main/Project_Image_Matplotlib_Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

Original_img = np.random.randint(0, 256,(10,10))
Inverted_img = 255 - Original_img

plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
plt.title('Original Image')
plt.imshow(Original_img, cmap='gray')
plt.axis("off")

plt.subplot(2,2,2)
plt.title('Inverted Image')
plt.imshow(Inverted_img, cmap='gray')
plt.axis("off")

plt.subplot(2,2,3)
plt.title('Histogram')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.hist(Original_img.ravel(), bins = 256)

plt.subplot(2,2,4)
plt.title("Training Loss")
epochs = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
loss = [20, 18, 15, 11, 10, 9, 3, 2, 1.8, 0]
plt.plot(epochs, loss, label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.show()
