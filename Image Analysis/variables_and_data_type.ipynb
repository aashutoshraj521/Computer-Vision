# %% [markdown]
# <a href="https://colab.research.google.com/github/aashutoshraj521/Python/blob/main/variables_and_data_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
research_area = "Computer Vision"
num_images = 500
learning_rate = 0.0001
use_gpu = True

# %%
print(research_area)
print(num_images)
print(learning_rate)
print(use_gpu)
# Out:
# Computer Vision
# 500
# 0.0001
# True

# %%
dataset_name = "BrainMRI"
num_classes = 2
accuracy = 97.5
is_trained = False

print(type(dataset_name))
print(type(num_classes))
print(type(accuracy))
print(type(is_trained))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
